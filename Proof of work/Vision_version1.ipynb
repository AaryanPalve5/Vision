# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLOv8
#
# ⚠️ YOLOv8 is still under heavy development. Breaking changes are being introduced almost weekly. We strive to make our YOLOv8 notebooks work with the latest version of the library. Last tests took place on **27.01.2023** with version **YOLOv8.0.20**.
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.
#
# YOLOv8 can be installed in two ways - from the source and via pip. This is because it is the first iteration of YOLO to have an official package.

# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.146 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.3/112.6 GB disk)

# %%
# Git clone method (for development)

# %cd {HOME}
# !git clone github.com/ultralytics/ultralytics
# %cd {HOME}/ultralytics
# !pip install -qe ultralytics

# from IPython import display
# display.clear_output()

# import ultralytics
# ultralytics.checks()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## CLI Basics

# %% [markdown]
# If you want to train, validate or run inference on models and don't need to make any modifications to the code, using YOLO command line interface is the easiest way to get started. Read more about CLI in [Ultralytics YOLO Docs](https://v8docs.ultralytics.com/cli/).
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %% [markdown]
# ## Inference with Pre-trained COCO Model

# %% [markdown]
# ### 💻 CLI

# %% [markdown]
# `yolo mode=predict` runs YOLOv8 inference on a variety of sources, downloading models automatically from the latest YOLOv8 release, and saving results to `runs/predict`.

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# ...
# 100% 6.25M/6.25M [00:00<00:00, 360MB/s]
# Ultralytics 8.3.146 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 104k/104k [00:00<00:00, 61.7MB/s]
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 145.5ms
# Speed: 14.4ms preprocess, 145.5ms inference, 727.5ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
# '2024-12-01 13-00-10.mov'
#  Aaryan_Palve_Resume-4.pdf
# 'Aaryan Suresh Palve-22-2.pdf'
# 'Aaryan Suresh Palve-22-3.pdf'
# 'Aaryan Suresh Palve-24.pdf'
#  Aaryan_Suresh_Palve_Resume.pdf
# 'Brothers Guitars'
# 'Colab Notebooks'
# 'Copy of 18200+ Ultimate HR Outreach List - DataNiti.gsheet'
# 'Copy of freedomtech 2.zip'
# 'CPMC 2k24'
#  DoorsWindows.zip
#  ENDSEM
# 'Farm Buddy - Brave 2024-07-26 21-46-02.mp4'
#  farmbuddyvid2.mp4
# 'HackFrost PITH - .mp4'
# 'Last dance'
#  Med_dataset.zip
#  Resume
#  Resume.pdf
#  Rob_Human_Dataset.zip

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !unzip /content/gdrive/MyDrive/DoorsWindows.zip
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists
# /content/datasets
# Archive:  /content/gdrive/MyDrive/DoorsWindows.zip
#    creating: Doors and Windows/
#   inflating: __MACOSX/._Doors and Windows
#   inflating: Doors and Windows/README.roboflow.txt
#   inflating: __MACOSX/Doors and Windows/._README.roboflow.txt
#    creating: Doors and Windows/valid/
#   inflating: __MACOSX/Doors and Windows/._valid
#   inflating: Doors and Windows/README.dataset.txt
#   inflating: __MACOSX/Doors and Windows/._README.dataset.txt
#    creating: Doors and Windows/test/
#   inflating: __MACOSX/Doors and Windows/._test
#   inflating: Doors and Windows/data.yaml
#   inflating: __MACOSX/Doors and Windows/._data.yaml
#    creating: Doors and Windows/train/
#   inflating: __MACOSX/Doors and Windows/._train
#    creating: Doors and Windows/valid/images/
#   inflating: __MACOSX/Doors and Windows/valid/._images
#    creating: Doors and Windows/valid/labels/
# ...

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data=/content/datasets/DoorsWindows/data.yaml epochs=100 imgsz=800 plots=True
# Out:
# /content
# Ultralytics 8.3.146 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8n.pt data=/content/datasets/data.yaml epochs=30 imgsz=640 batch=16 workers=2 patience=5 plots=True
